# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.mixture import GaussianMixture

# %%
X_train = np.load(r'./data/data.npy')

# %%
plt.figure(figsize=(6, 6))
plt.plot(X_train[:,0], X_train[:, 1], 'bx')
plt.axis('equal')

plt.show()
